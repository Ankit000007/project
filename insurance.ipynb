# %%
import pandas as pd, numpy as np, seaborn as sns, matplotlib.pyplot as plt, joblib
from scipy.stats import zscore

#Encode
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

#Skewness
from sklearn.preprocessing import PowerTransformer

#Normalize
from sklearn.preprocessing import MinMaxScaler

#Train Test Split
from sklearn.model_selection import train_test_split

#Metrics
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

#RegressionModels
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR,LinearSVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

#Optimization
from sklearn.model_selection import GridSearchCV

# %%
df=pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...  \
# 0  Bachelor           2/24/11         Employed  ...
# 1  Bachelor           1/31/11       Unemployed  ...
# 2  Bachelor           2/19/11         Employed  ...
# 3  Bachelor           1/20/11       Unemployed  ...
# 4  Bachelor            2/3/11         Employed  ...
#
#   Months Since Policy Inception  Number of Open Complaints Number of Policies  \
# 0                             5                          0                  1
# 1                            42                          0                  8
# 2                            38                          0                  2
# 3                            65                          0                  7
# 4                            44                          0                  1
#
#       Policy Type        Policy  Claim Reason  Sales Channel  \
# 0  Corporate Auto  Corporate L3     Collision          Agent
# 1   Personal Auto   Personal L3  Scratch/Dent          Agent
# 2   Personal Auto   Personal L3     Collision          Agent
# 3  Corporate Auto  Corporate L2     Collision    Call Center
# 4   Personal Auto   Personal L1     Collision          Agent
#
#    Total Claim Amount  Vehicle Class Vehicle Size
# 0          384.811147   Two-Door Car      Medsize
# 1         1131.464935  Four-Door Car      Medsize
# 2          566.472247   Two-Door Car      Medsize
# 3          529.881344            SUV      Medsize
# 4          138.130879  Four-Door Car      Medsize
#
# [5 rows x 26 columns]

# %%
#Check info
df.info()
#There are no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   Country                        9134 non-null   object
#  2   State Code                     9134 non-null   object
#  3   State                          9134 non-null   object
#  4   Claim Amount                   9134 non-null   float64
#  5   Response                       9134 non-null   object
#  6   Coverage                       9134 non-null   object
#  7   Education                      9134 non-null   object
#  8   Effective To Date              9134 non-null   object
#  9   EmploymentStatus               9134 non-null   object
#  10  Gender                         9134 non-null   object
#  11  Income                         9134 non-null   int64
#  12  Location Code                  9134 non-null   object
#  13  Marital Status                 9134 non-null   object
#  14  Monthly Premium Auto           9134 non-null   int64
#  15  Months Since Last Claim        9134 non-null   int64
#  16  Months Since Policy Inception  9134 non-null   int64
#  17  Number of Open Complaints      9134 non-null   int64
#  18  Number of Policies             9134 non-null   int64
#  19  Policy Type                    9134 non-null   object
#  20  Policy                         9134 non-null   object
#  21  Claim Reason                   9134 non-null   object
#  22  Sales Channel                  9134 non-null   object
#  23  Total Claim Amount             9134 non-null   float64
#  24  Vehicle Class                  9134 non-null   object
#  25  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(18)
# memory usage: 1.8+ MB

# %%
#Check Stats
df.describe()
# Out:
#        Claim Amount        Income  Monthly Premium Auto  \
# count   9134.000000   9134.000000           9134.000000
# mean     800.494047  37657.380009             93.219291
# std      687.096761  30379.904734             34.407967
# min      189.800768      0.000000             61.000000
# 25%      399.425179      0.000000             68.000000
# 50%      578.018220  33889.500000             83.000000
# 75%      896.216704  62320.000000            109.000000
# max     8332.538119  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# 75%                  23.000000                      71.000000
# max                  35.000000                      99.000000
#
#        Number of Open Complaints  Number of Policies  Total Claim Amount
# count                9134.000000         9134.000000         9134.000000
# mean                    0.384388            2.966170          434.088794
# std                     0.910384            2.390182          290.500092
# min                     0.000000            1.000000            0.099007
# 25%                     0.000000            1.000000          272.258244
# 50%                     0.000000            2.000000          383.945434
# 75%                     0.000000            4.000000          547.514839
# max                     5.000000            9.000000         2893.239678

# %%
df.isna().sum()
#There are no missing values
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
df.select_dtypes('object').columns
# Out:
# Index(['Customer', 'Country', 'State Code', 'State', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Location Code', 'Marital Status', 'Policy Type', 'Policy',
#        'Claim Reason', 'Sales Channel', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
df['Customer'].nunique()
# Out:
# 9134

# %%
df=df.drop('Customer',axis=1)

# %%
df['Country'].nunique()
# Out:
# 1

# %%
df['Country'].value_counts()
# Out:
# US    9134
# Name: Country, dtype: int64

# %%
df=df.drop('Country',axis=1)

# %%
df['State Code'].nunique()
# Out:
# 5

# %%
df['State Code'].value_counts()
# Out:
# MO    3150
# IA    2601
# NE    1703
# OK     882
# KS     798
# Name: State Code, dtype: int64

# %%
df=pd.concat([df.drop('State Code',axis=1),pd.get_dummies(df['State Code'])],axis=1)

# %%
df['State'].nunique()
# Out:
# 5

# %%
#This are same values as State Code
df['State'].value_counts()
# Out:
# Missouri    3150
# Iowa        2601
# Nebraska    1703
# Oklahoma     882
# Kansas       798
# Name: State, dtype: int64

# %%
df=df.drop('State',axis=1)

# %%
df['Response'].nunique()
# Out:
# 2

# %%
df['Response'].value_counts()
# Out:
# No     7826
# Yes    1308
# Name: Response, dtype: int64

# %%
le=LabelEncoder()
df['Response']=le.fit_transform(df['Response'])
df['Coverage'].nunique()
# Out:
# 3

# %%
df['Coverage'].value_counts()
# Out:
# Basic       5568
# Extended    2742
# Premium      824
# Name: Coverage, dtype: int64

# %%
df=pd.concat([df.drop('Coverage',axis=1),pd.get_dummies(df['Coverage'])],axis=1)
df['Education'].nunique()
# Out:
# 5

# %%
df['Education'].value_counts()
# Out:
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: Education, dtype: int64

# %%
df=pd.concat([df.drop('Education',axis=1),pd.get_dummies(df['Education'])],axis=1)

# %%
df['Effective To Date']=pd.to_datetime(df['Effective To Date'],format='%m/%d/%y')

# %%
df['Effective To Date'].dt.year.nunique()
#Data has been taken for only one year hence we will not bifurcate year from this column
#Instead we will only create a new clumn for month
# Out:
# 1

# %%
df['Effective Month']=df['Effective To Date'].dt.month

# %%
#Drop Effective to Date column as month has already been extracted
df=df.drop('Effective To Date',axis=1)
df['EmploymentStatus'].nunique()
# Out:
# 5

# %%
df['EmploymentStatus'].value_counts()
# Out:
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: EmploymentStatus, dtype: int64

# %%
df=pd.concat([df.drop('EmploymentStatus',axis=1),pd.get_dummies(df['EmploymentStatus'])],axis=1)
#We have encoded the values in different columns so that model does not consider it as a rank or order

# %%
df['Gender'].nunique()
#Since there are only two values we will label encode it
# Out:
# 2

# %%
df['Gender']=le.fit_transform(df['Gender'])
df['Location Code'].nunique()
# Out:
# 3

# %%
df['Location Code'].value_counts()
# Out:
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: Location Code, dtype: int64

# %%
df=pd.concat([df.drop('Location Code',axis=1),pd.get_dummies(df['Location Code'])],axis=1)
#We have encoded the values in different columns so that model does not consider it as a rank or order

# %%
df['Policy'].nunique()
# Out:
# 9

# %%
df['Policy'].value_counts()
#We will LabelEncode this values
# Out:
# Personal L3     3426
# Personal L2     2122
# Personal L1     1240
# Corporate L3    1014
# Corporate L2     595
# Corporate L1     359
# Special L2       164
# Special L3       148
# Special L1        66
# Name: Policy, dtype: int64

# %%
df['Policy']=le.fit_transform(df['Policy'])

# %%
df['Claim Reason'].nunique()
# Out:
# 4

# %%
df['Claim Reason'].value_counts()
# Out:
# Collision       3752
# Hail            2926
# Scratch/Dent    1432
# Other           1024
# Name: Claim Reason, dtype: int64

# %%
df['Claim Reason']=le.fit_transform(df['Claim Reason'])

# %%
df['Sales Channel'].nunique()
# Out:
# 4

# %%
df['Sales Channel'].value_counts()
# Out:
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# Name: Sales Channel, dtype: int64

# %%
df['Sales Channel']=le.fit_transform(df['Sales Channel'])

# %%
df['Vehicle Class'].nunique()
# Out:
# 6

# %%
df['Vehicle Class'].value_counts()
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: Vehicle Class, dtype: int64

# %%
df=pd.concat([df.drop('Vehicle Class',axis=1),pd.get_dummies(df['Vehicle Class'])],axis=1)
#We have encoded the values in different columns so that model does not consider it as a rank or order

# %%
df['Vehicle Size'].nunique()
# Out:
# 3

# %%
df['Vehicle Size'].value_counts()
# Out:
# Medsize    6424
# Small      1764
# Large       946
# Name: Vehicle Size, dtype: int64

# %%
df=pd.concat([df.drop('Vehicle Size',axis=1),pd.get_dummies(df['Vehicle Size'])],axis=1)
#We have encoded the values in different columns so that model does not consider it as a rank or order

# %%
#Check for object types again
df.select_dtypes('object').columns
#There are no columns for object type
# Out:
# Index(['Marital Status', 'Policy Type'], dtype='object')

# %%
#Check for correlation
plt.figure(figsize=(10,6))
df.corr()['Total Claim Amount'].drop('Total Claim Amount').sort_values(ascending=False).plot(kind='bar')
plt.show()

# %%
df.corr()['Total Claim Amount'].drop('Total Claim Amount').sort_values(ascending=False)
# Out:
# Monthly Premium Auto             0.632017
# Suburban                         0.578640
# Unemployed                       0.332138
# Luxury SUV                       0.325004
# Luxury Car                       0.323061
# Premium                          0.235561
# SUV                              0.230744
# Claim Amount                     0.226451
# High School or Below             0.115995
# Extended                         0.104822
# Sports Car                       0.101023
# Small                            0.093198
# Gender                           0.074564
# Retired                          0.034293
# Disabled                         0.030123
# Medical Leave                    0.029028
# Response                         0.016877
# MO                               0.009318
# Months Since Last Claim          0.007563
# Effective Month                  0.006820
# OK                               0.005247
# Months Since Policy Inception    0.003335
# KS                               0.002402
# Policy                           0.000858
# IA                              -0.002338
# Number of Policies              -0.002354
# Large                           -0.009391
# Sales Channel                   -0.010055
# Bachelor                        -0.013764
# Number of Open Complaints       -0.014241
# NE                              -0.014383
# College                         -0.022802
# Doctor                          -0.065114
# Claim Reason                    -0.071871
# Medsize                         -0.074274
# Master                          -0.085771
# Two-Door Car                    -0.146712
# Urban                           -0.164678
# Basic                           -0.236817
# Four-Door Car                   -0.286789
# Employed                        -0.336091
# Income                          -0.355254
# Rural                           -0.547715
# Name: Total Claim Amount, dtype: float64

# %%
#Check for correlation
plt.figure(figsize=(10,6))
df.corr()['Total Claim Amount'].drop('Total Claim Amount').sort_values(ascending=False).plot(kind='bar')
plt.show()

# %%
#Check for correlation
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,cmap='viridis')
plt.show()

# %%
#Check for skewness
df.skew()
# Out:
# Claim Amount                     3.032280
# Response                         2.037567
# Gender                           0.039866
# Income                           0.286887
# Monthly Premium Auto             2.123546
# Months Since Last Claim          0.278586
# Months Since Policy Inception    0.040165
# Number of Open Complaints        2.783263
# Number of Policies               1.253333
# Policy                          -0.427639
# Claim Reason                     0.733526
# Sales Channel                    0.506774
# Total Claim Amount               1.714966
# IA                               0.954022
# KS                               2.923123
# MO                               0.652860
# NE                               1.610436
# OK                               2.732278
# Basic                           -0.449361
# Extended                         0.871991
# Premium                          2.861258
# Bachelor                         0.868583
# College                          0.907014
# Doctor                           4.873839
# High School or Below             0.941559
# Master                           3.068871
# Effective Month                  0.145359
# Disabled                         4.427858
# Employed                        -0.511300
# Medical Leave                    4.266045
# Retired                          5.425089
# Unemployed                       1.132463
# Rural                            1.547052
# Suburban                        -0.550594
# Urban                            1.727474
# Four-Door Car                   -0.023653
# Luxury Car                       7.285081
# Luxury SUV                       6.832071
# SUV                              1.526848
# Sports Car                       3.991627
# Two-Door Car                     1.450502
# Large                            2.602528
# Medsize                         -0.890278
# Small                            1.555039
# dtype: float64

# %%
df.skew()
# Out:
# Claim Amount                     0.578248
# Response                         2.037567
# Gender                           0.039866
# Income                           0.286887
# Monthly Premium Auto             2.123546
# Months Since Last Claim          0.278586
# Months Since Policy Inception    0.040165
# Number of Open Complaints        2.783263
# Number of Policies               1.253333
# Policy                          -0.427639
# Claim Reason                     0.733526
# Sales Channel                    0.506774
# Total Claim Amount               1.714966
# IA                               0.954022
# KS                               2.923123
# MO                               0.652860
# NE                               1.610436
# OK                               2.732278
# Basic                           -0.449361
# Extended                         0.871991
# Premium                          2.861258
# Bachelor                         0.868583
# College                          0.907014
# Doctor                           4.873839
# High School or Below             0.941559
# Master                           3.068871
# Effective Month                  0.145359
# Disabled                         4.427858
# Employed                        -0.511300
# Medical Leave                    4.266045
# Retired                          5.425089
# Unemployed                       1.132463
# Rural                            1.547052
# Suburban                        -0.550594
# Urban                            1.727474
# Four-Door Car                   -0.023653
# Luxury Car                       7.285081
# Luxury SUV                       6.832071
# SUV                              1.526848
# Sports Car                       3.991627
# Two-Door Car                     1.450502
# Large                            2.602528
# Medsize                         -0.890278
# Small                            1.555039
# dtype: float64

# %%
pt=PowerTransformer()

# %%
#Standardize/Normalize the data
scale=MinMaxScaler()

# %%
X=df.drop('Total Claim Amount',axis=1)
y=df['Total Claim Amount']

# %%
def model_sel(mod):
    maxscore=0
    maxstate=0
    for x in range(42,105):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=x)
        model=mod()
        model.fit(X_train,y_train)
        predict=model.predict(X_test)
        r2score=r2_score(y_test,predict)
        if r2score>maxscore:
            maxscore=r2score
            maxstate=x
    print("Max Score is {} at max state {}".format(maxscore,maxstate))

# %%
model_sel(LinearRegression)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-209008f0e28c> in <module>
# ----> 1 model_sel(LinearRegression)
#
# <ipython-input-83-fac0043d103d> in model_sel(mod)
#       5         X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=x)
#       6         model=mod()
# ----> 7         model.fit(X_train,y_train)
#       8         predict=model.predict(X_test)
#       9         r2score=r2_score(y_test,predict)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Married'

# %%
model_sel(Ridge)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-105afa2e1ec9> in <module>
# ----> 1 model_sel(Ridge)
#
# <ipython-input-83-fac0043d103d> in model_sel(mod)
#       5         X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=x)
#       6         model=mod()
# ----> 7         model.fit(X_train,y_train)
#       8         predict=model.predict(X_test)
#       9         r2score=r2_score(y_test,predict)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py in fit(self, X, y, sample_weight)
#     764         self : returns an instance of self.
#     765         """
# --> 766         return super().fit(X, y, sample_weight=sample_weight)
#     767
#     768
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py in fit(self, X, y, sample_weight)
#     545                          accept_sparse=_accept_sparse,
#     546                          dtype=_dtype,
# --> 547                          multi_output=True, y_numeric=True)
#     548         if sparse.issparse(X) and self.fit_intercept:
#     549             if self.solver not in ['auto', 'sparse_cg', 'sag']:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Married'

# %%
model_sel(Lasso)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-5cfc2d510ac2> in <module>
# ----> 1 model_sel(Lasso)
#
# <ipython-input-83-fac0043d103d> in model_sel(mod)
#       5         X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=x)
#       6         model=mod()
# ----> 7         model.fit(X_train,y_train)
#       8         predict=model.predict(X_test)
#       9         r2score=r2_score(y_test,predict)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in fit(self, X, y, check_input)
#     700             X, y = check_X_y(X, y, accept_sparse='csc',
#     701                              order='F', dtype=[np.float64, np.float32],
# --> 702                              copy=X_copied, multi_output=True, y_numeric=True)
#     703             y = check_array(y, order='F', copy=False, dtype=X.dtype.type,
#     704                             ensure_2d=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Married'

# %%
model_sel(ElasticNet)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-788ebf59052e> in <module>
# ----> 1 model_sel(ElasticNet)
#
# <ipython-input-83-fac0043d103d> in model_sel(mod)
#       5         X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=x)
#       6         model=mod()
# ----> 7         model.fit(X_train,y_train)
#       8         predict=model.predict(X_test)
#       9         r2score=r2_score(y_test,predict)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in fit(self, X, y, check_input)
#     700             X, y = check_X_y(X, y, accept_sparse='csc',
#     701                              order='F', dtype=[np.float64, np.float32],
# --> 702                              copy=X_copied, multi_output=True, y_numeric=True)
#     703             y = check_array(y, order='F', copy=False, dtype=X.dtype.type,
#     704                             ensure_2d=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Married'

# %%
model_sel(KNeighborsRegressor)

# %%
model_sel(DecisionTreeRegressor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-8f1588e6f618> in <module>
# ----> 1 model_sel(DecisionTreeRegressor)
#
# NameError: name 'model_sel' is not defined

# %%
model_sel(RandomForestRegressor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-10f710288c1d> in <module>
# ----> 1 model_sel(RandomForestRegressor)
#
# NameError: name 'model_sel' is not defined

# %%
model_sel(SVR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-906426c4d2c8> in <module>
# ----> 1 model_sel(SVR)
#
# NameError: name 'model_sel' is not defined

# %%
model_sel(AdaBoostRegressor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-496c80629438> in <module>
# ----> 1 model_sel(AdaBoostRegressor)
#
# NameError: name 'model_sel' is not defined

# %%
#From the above results max score is for RandomForestRegressor at 83 random state
#we will try to hypertune the parameters of RandomForestRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-c663d03a3802> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=75)
#
# NameError: name 'X' is not defined

# %%
param={'n_estimators':[100,110,130,150,170,210,230,270,310,330,350,370,390,510]}
gscv=GridSearchCV(RandomForestRegressor(),param)

# %%
gscv.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-503b55829aee> in <module>
# ----> 1 gscv.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined

# %%
gscv.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-9020b41a5225> in <module>
# ----> 1 gscv.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
rf=RandomForestRegressor(n_estimators=350)
rf.fit(X_train,y_train)
predict=rf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-0b3ff5e6dc38> in <module>
#       1 rf=RandomForestRegressor(n_estimators=350)
# ----> 2 rf.fit(X_train,y_train)
#       3 predict=rf.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
print("r2score is {}".format(r2_score(y_test,predict)))
print("MAE is {}".format(mean_absolute_error(y_test,predict)))
print("MSE is {}".format(mean_squared_error(y_test,predict)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-b5c5eba476b8> in <module>
# ----> 1 print("r2score is {}".format(r2_score(y_test,predict)))
#       2 print("MAE is {}".format(mean_absolute_error(y_test,predict)))
#       3 print("MSE is {}".format(mean_squared_error(y_test,predict)))
#
# NameError: name 'y_test' is not defined

# %%
result=pd.DataFrame(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-7503d323dd50> in <module>
# ----> 1 result=pd.DataFrame(y_test)
#
# NameError: name 'y_test' is not defined

# %%
result=pd.concat([result.reset_index().drop('index',axis=1),pd.Series(predict)],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-0c669f6be8b0> in <module>
# ----> 1 result=pd.concat([result.reset_index().drop('index',axis=1),pd.Series(predict)],axis=1)
#
# NameError: name 'result' is not defined

# %%
result.columns=['Total Claim Amount','Total Predicted Claim Amount']

plt.figure(figsize=(10,6))
sns.scatterplot(x='Total Claim Amount',y='Total Predicted Claim Amount',data=result)
plt.show()
#The below plot shows linear behaviour in predicted and original values which is satisfactory
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-a9ee0b6d7865> in <module>
# ----> 1 result.columns=['Total Claim Amount','Total Predicted Claim Amount']
#       2
#       3 plt.figure(figsize=(10,6))
#       4 sns.scatterplot(x='Total Claim Amount',y='Total Predicted Claim Amount',data=result)
#       5 plt.show()
#
# NameError: name 'result' is not defined

# %%
#Save the model
joblib.dump(rf,'Insurance.obj')
# Out:
# ['Insurance.obj']
